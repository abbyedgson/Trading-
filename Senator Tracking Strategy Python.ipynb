# %% [markdown]
# # FINM3414 Trading Assignment
# #### Team 19: Abby Edgson (45856806), Blake Woodhall (46970660), Mustafa Durmaz (47040355)

# %% [markdown]
# ## Strategy
# The senator tracking quant trading strategy tracks the stock purchases and sales disclosed by congress members. Under the 2012 Congressional Knowledge Act, any stock trade valued over USD 1000 made by a member of Congress or their immediate family must be disclosed publicly and quickly (112th Congress, 2012). This act was passed to combat insider information and the impacts of conflicts of interest among this group of lawmakers. Between 2019 and 2021, more than half of the senators who traded sat on congressional committees that potentially gave them access to insider information on the companies whose shares they disclosed buying or selling, with more than 3,700 trades posing conflicts of interest between public responsibility and personal finances (Kelly, Playford, & Parlapiano, 2022). A study conducted by the University of Arkansas found that the stocks purchased by US senators generated positive abnormal returns between 2012 and 2020 (Ridge, 2022). Based on this information, we have chosen to track senator trades as a quant trading strategy. This strategy was inspired by Quiver Quantitative Senate Trading strategy (Quiver Quantitative, 2023).
#
# This method will use daily rebalancing to realign the portfolio with the current senator trades, ensuring an up-to-date portfolio.
#
# Our strategy will explore two methods: the Congress long-only and the long-short portfolio. The long-only portfolio will involve stocks with a long position based on senator purchases, while the long-short portfolio will incorporate short positions based on senate stock sales.

# %% [markdown]
# ### Importing Libraries:

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bs4 as bs
import requests
import yfinance as yf
import datetime
from datetime import datetime
from collections import defaultdict

# %% [markdown]
# ### Downloading senator trading information using an API that tracks sentor trades:
#
# The amount of stock that is traded is listed as a range, this strategy will use the midpoint of this range. The output will generate the date, ticker, amount and the type of transaction.

# %%
# Computing the midpoint of the range:
def compute_midpoint(amount_str):
    # If the amount is 'Unknown', return None
    if amount_str == 'Unknown':
        return None

    # Remove dollar signs and split on '-'
    ranges = amount_str.replace('$', '').split('-')
    
    # If there's only one value, return it
    if len(ranges) == 1:
        return int(ranges[0].replace(',', '').strip())
    
    # Convert to integers
    lower_bound = int(ranges[0].replace(',', '').strip())
    upper_bound = int(ranges[1].replace(',', '').strip())
    
    # Return the midpoint
    return (lower_bound + upper_bound) / 2


# Simplifing the transaction type to show sale or purchase
def simplify_transaction_type(transaction_type):
    if "Sale" in transaction_type:
        return "Sale"
    elif "Purchase" in transaction_type:
        return "Purchase"
    else:
        return None  # for any other types

url = "https://senate-stock-watcher-data.s3-us-west-2.amazonaws.com/aggregate/all_transactions.json"
response = requests.get(url)

# Ensure the request was successful
if response.status_code == 200:
    data = response.json()
    
    transactions = []
    for transaction in data:
        transaction_date = transaction.get('transaction_date', None)
        ticker = transaction.get('ticker', None)
        amount = transaction.get('amount', None)
        transaction_type = transaction.get('type', None)
        
        # Simplify the transaction type
        simple_type = simplify_transaction_type(transaction_type)
        
        # Compute the midpoint of the amount range
        midpoint_amount = compute_midpoint(amount)
        
        # Skip transactions where ticker is 'N/A' or amount is 'Unknown' or simple_type is None
        if ticker != 'N/A' and amount != 'Unknown' and transaction_date and simple_type and midpoint_amount is not None:
            transactions.append({
                'transaction_date': transaction_date,
                'ticker': ticker,
                'amount': midpoint_amount,
                'type': simple_type
            })

    # Print the transactions
    for trans in transactions:
        print(trans)
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# {'transaction_date': '04/18/2023', 'ticker': 'ESS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/18/2023', 'ticker': 'ESS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/04/2023', 'ticker': 'UPS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/04/2023', 'ticker': 'MCD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/04/2023', 'ticker': 'DUK', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'TTD', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'PTON', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'DIS', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'CMCSA', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'CCCS', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'AMZN', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'BABA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'SNAP', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'PINS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/12/2023', 'ticker': 'CARG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/12/2023', 'ticker': 'BBY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '05/01/2023', 'ticker': 'CMG', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2023', 'ticker': 'F', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '04/27/2023', 'ticker': 'F', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '04/26/2023', 'ticker': 'F', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '04/26/2023', 'ticker': 'ATVI', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '04/24/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/24/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/24/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/24/2023', 'ticker': 'X', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '04/24/2023', 'ticker': 'X', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '04/24/2023', 'ticker': 'CLF', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '04/18/2023', 'ticker': 'OXY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/14/2023', 'ticker': 'KMB', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/14/2023', 'ticker': 'MMM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/14/2023', 'ticker': 'MRO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2023', 'ticker': 'KR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2023', 'ticker': 'MDLZ', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2023', 'ticker': 'PARA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2023', 'ticker': 'HPQ', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/04/2023', 'ticker': 'TSLA', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'TXN', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'XP', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'VCTR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'VZ', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'TREX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'MMM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'TMO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'MSFT', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'TSLA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'SKY', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'SSD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'SCI', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'QSR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'REGN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'RRC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'RH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'PHM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'PAM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'NSC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'NDSN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'NVDA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'MCO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'MPWR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'MPWR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'MTD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'MMC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'MKSI', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'LMST', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'ITW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'IDXX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'GFI', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'FLT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'META', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'ETSY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'EW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'DQ', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'CROX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'CSCO', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'ANET', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'AMT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'ALLE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'ABBV', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2023', 'ticker': 'GSK', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'GNTX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'GRMN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'DIOD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'CBSH', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'CRUS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'AVGO', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'ADSK', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2023', 'ticker': 'APH', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2022', 'ticker': 'A', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/26/2023', 'ticker': 'NVS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/26/2023', 'ticker': 'TMO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'FIMKX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'FCPIX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'JHMM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'SBIO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'LGI', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'BRKR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'AVNT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'FDN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'RTH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'SNDR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'DGRS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'MRVL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'ALGM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'DIOD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2023', 'ticker': 'VSH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/13/2023', 'ticker': 'UAA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/13/2023', 'ticker': 'UA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/13/2023', 'ticker': 'CSCO', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/11/2023', 'ticker': 'ITW', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/05/2023', 'ticker': 'CSII', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '04/05/2023', 'ticker': 'MDT', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '04/05/2023', 'ticker': 'CSII', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '03/14/2023', 'ticker': 'TFC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/14/2023', 'ticker': 'O', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '03/13/2023', 'ticker': 'NUE', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'TSM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/21/2023', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'X', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'X', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'X', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'X', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '03/21/2023', 'ticker': 'CLF', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '03/20/2023', 'ticker': 'X', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '03/10/2023', 'ticker': 'KMB', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '03/06/2023', 'ticker': 'BMO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/03/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/07/2023', 'ticker': 'AAPL', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '01/19/2022', 'ticker': 'TSM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/03/2023', 'ticker': 'WFC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/10/2023', 'ticker': 'SCHW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/21/2023', 'ticker': 'CHD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/10/2023', 'ticker': 'CHD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/10/2023', 'ticker': 'GOOG', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'QCOM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/21/2023', 'ticker': 'SBUX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/21/2023', 'ticker': 'VFH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/21/2023', 'ticker': 'SQM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'WM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'TSM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/21/2023', 'ticker': 'AGX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'KBE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/21/2023', 'ticker': 'HASI', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'MOS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'FPI', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'RTH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/21/2023', 'ticker': 'BSM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'RTX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2023', 'ticker': 'IRM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/21/2023', 'ticker': 'APO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'ABYIX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'MBXIX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'LUBYX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'JHMM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'VHT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/15/2023', 'ticker': 'SBIO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'IVV', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/15/2023', 'ticker': 'IJR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/15/2023', 'ticker': 'IWD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/15/2023', 'ticker': 'CDL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'SPGP', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'GNR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'LDP', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'QTEC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/15/2023', 'ticker': 'FDN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'RTH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'MOO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'IGHG', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/15/2023', 'ticker': 'GBIL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/15/2023', 'ticker': 'FDRR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'FQAL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/15/2023', 'ticker': 'NXTG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/23/2023', 'ticker': 'GOLD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/18/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/18/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/18/2023', 'ticker': 'CLF', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '01/13/2023', 'ticker': 'UAA', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '01/12/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'V', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'KO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'AAPL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'TXN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'X', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/05/2023', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'X', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'X', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '01/05/2023', 'ticker': 'CLF', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '01/10/2023', 'ticker': 'ULTA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/10/2023', 'ticker': 'PXD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/10/2023', 'ticker': 'JPM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/10/2023', 'ticker': 'CVS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/10/2023', 'ticker': 'BMY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/10/2023', 'ticker': 'BKNG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/10/2023', 'ticker': 'ZTS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/10/2023', 'ticker': 'AMZN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/10/2023', 'ticker': 'ALGN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/18/2023', 'ticker': 'RIO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/18/2023', 'ticker': 'FPI', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/12/2023', 'ticker': 'AQN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/04/2023', 'ticker': 'MAXR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/04/2023', 'ticker': 'MGM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'AMT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'SRVR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'MOO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'ATKR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'HOLX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'BHP', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'RMD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'CVS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'TU', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'DLR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'AXS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/11/2023', 'ticker': 'CME', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'SAND', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'BSM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'URA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'FLNG', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'EQNR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/11/2023', 'ticker': 'MCD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/28/2022', 'ticker': 'RNWK', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '12/23/2022', 'ticker': 'GOLD', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '12/19/2022', 'ticker': 'NU', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '12/15/2022', 'ticker': 'DIS', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'KMB', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PYPL', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'CLX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PYPL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PYPL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PYPL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PYPL', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PYPL', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '12/09/2022', 'ticker': 'PYPL', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '12/08/2022', 'ticker': 'PYPL', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '12/06/2022', 'ticker': 'GOLD', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '12/05/2022', 'ticker': 'PYPL', 'amount': 375000.5, 'type': 'Purchase'}
# {'transaction_date': '12/02/2022', 'ticker': 'QCOM', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '12/02/2022', 'ticker': 'QCOM', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '12/01/2022', 'ticker': 'QCOM', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '12/01/2022', 'ticker': 'GOLD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/29/2022', 'ticker': 'C', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/29/2022', 'ticker': 'C', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '12/14/2022', 'ticker': 'FWONK', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '12/05/2022', 'ticker': 'LSXMK', 'amount': 375000.5, 'type': 'Sale'}
# {'transaction_date': '12/05/2022', 'ticker': 'LSXMK', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '11/29/2022', 'ticker': 'LBRDK', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '11/29/2022', 'ticker': 'LBRDK', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '11/30/2022', 'ticker': 'SYK', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'PYPL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'META', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'MDT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'MLM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'FFIV', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'ELAN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'CMCSA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'BAX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'GOOG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'ADBE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/30/2022', 'ticker': 'RPM', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '11/22/2022', 'ticker': 'DIS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'NVDA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'META', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'AAPL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'AMZN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'GOOG', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'ADBE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'DIS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'NVDA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'META', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'AAPL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'AMZN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'GOOG', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'ADBE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'DIS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'NVDA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'META', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'AAPL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'AMZN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'GOOG', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'ADBE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/30/2022', 'ticker': 'ZTS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/30/2022', 'ticker': 'TJX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/30/2022', 'ticker': 'TMO', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/30/2022', 'ticker': 'MSFT', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '11/30/2022', 'ticker': 'LRCX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/23/2022', 'ticker': 'TSM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/23/2022', 'ticker': 'TSM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/23/2022', 'ticker': 'MSFT', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '11/23/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/22/2022', 'ticker': 'INTC', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '11/22/2022', 'ticker': 'MSFT', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '11/22/2022', 'ticker': 'F', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '11/17/2022', 'ticker': 'F', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '11/09/2022', 'ticker': 'INTC', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '11/08/2022', 'ticker': 'PYPL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/08/2022', 'ticker': 'PYPL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/08/2022', 'ticker': 'PYPL', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '11/08/2022', 'ticker': 'PYPL', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '11/08/2022', 'ticker': 'ATVI', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '11/07/2022', 'ticker': 'PYPL', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '11/03/2022', 'ticker': 'CLF', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '11/01/2022', 'ticker': 'NU', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/01/2022', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/08/2022', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/29/2022', 'ticker': 'WIW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/29/2022', 'ticker': 'GBIL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/29/2022', 'ticker': 'WIW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/29/2022', 'ticker': 'GBIL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/15/2022', 'ticker': 'WIW', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '11/15/2022', 'ticker': 'GBIL', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '11/08/2022', 'ticker': 'LUBYX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/08/2022', 'ticker': 'WIW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/08/2022', 'ticker': 'LDP', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '11/08/2022', 'ticker': 'GBIL', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '11/23/2022', 'ticker': 'BATRK', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '11/23/2022', 'ticker': 'BATRK', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '11/14/2022', 'ticker': 'LBRDA', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '11/14/2022', 'ticker': 'LBRDA', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '11/21/2022', 'ticker': 'BATRA', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '11/21/2022', 'ticker': 'BATRA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '11/21/2022', 'ticker': 'BATRK', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '11/21/2022', 'ticker': 'BATRK', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/28/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/31/2022', 'ticker': 'CLF', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '10/28/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/28/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/24/2022', 'ticker': 'MSFT', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '10/13/2022', 'ticker': 'NU', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '10/13/2022', 'ticker': 'MSFT', 'amount': 375000.5, 'type': 'Purchase'}
# {'transaction_date': '10/11/2022', 'ticker': 'NU', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'XOM', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '10/06/2022', 'ticker': 'CVX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '10/06/2022', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/06/2022', 'ticker': 'X', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '10/06/2022', 'ticker': 'NU', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'VCTR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'VCTR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'VCTR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'VRTX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'TREX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'SCI', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'RELX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'RH', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'PHM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'PAYC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'GIS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'GLPI', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'RACE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'XOM', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'EXR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'ETSY', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'ELS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'DQ', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'CROX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'CSCO', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/06/2022', 'ticker': 'AMGN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/05/2022', 'ticker': 'AMT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/05/2022', 'ticker': 'ZTS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'WIT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'SEIC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'RMD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'TROW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'NOC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'NVDA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'MNST', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'MSFT', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'MASI', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'MKTX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'IDXX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'HON', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'GGG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'IT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'GRMN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'FAST', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'EL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'DHI', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'CHD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'AMAT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'ALGN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'APD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/04/2022', 'ticker': 'MRO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/04/2022', 'ticker': 'OXY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/04/2022', 'ticker': 'OXY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/04/2022', 'ticker': 'OXY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/04/2022', 'ticker': 'OXY', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/25/2022', 'ticker': 'FTBFX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '10/25/2022', 'ticker': 'FDX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/27/2022', 'ticker': 'BMN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'MBXIX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'GSMYX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/17/2022', 'ticker': 'SBPYX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'FCPIX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/17/2022', 'ticker': 'VZ', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/17/2022', 'ticker': 'CVS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'DLR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/17/2022', 'ticker': 'TSM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'MPW', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'SRVR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/17/2022', 'ticker': 'LDP', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/17/2022', 'ticker': 'EFAD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'GMRE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/17/2022', 'ticker': 'JHEM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'ABT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/17/2022', 'ticker': 'DIS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/17/2022', 'ticker': 'INTC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/10/2022', 'ticker': 'HDGE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/10/2022', 'ticker': 'HDGE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/10/2022', 'ticker': 'PSQ', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/10/2022', 'ticker': 'HDGE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/10/2022', 'ticker': 'HDGE', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '10/05/2022', 'ticker': 'PSQ', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'PSQ', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'SH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/05/2022', 'ticker': 'HDGE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '10/05/2022', 'ticker': 'PSQ', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '10/04/2022', 'ticker': 'HQL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '10/04/2022', 'ticker': 'NID', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '10/04/2022', 'ticker': 'SBIO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/30/2022', 'ticker': 'FIVE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '09/20/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '09/20/2022', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '09/19/2022', 'ticker': 'X', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '09/19/2022', 'ticker': 'MSFT', 'amount': 375000.5, 'type': 'Purchase'}
# {'transaction_date': '09/19/2022', 'ticker': 'ARKK', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '09/12/2022', 'ticker': 'F', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '09/12/2022', 'ticker': 'F', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '09/12/2022', 'ticker': 'F', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '09/07/2022', 'ticker': 'ECOM', 'amount': 750000.5, 'type': 'Sale'}
# {'transaction_date': '09/07/2022', 'ticker': 'ARKK', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '09/06/2022', 'ticker': 'NU', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '09/19/2022', 'ticker': 'SH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '09/19/2022', 'ticker': 'SH', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '09/19/2022', 'ticker': 'SH', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '09/08/2022', 'ticker': 'SQM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '09/06/2022', 'ticker': 'WFC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/01/2022', 'ticker': 'IVV', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'EFAV', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'XLY', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'VTRS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'ABNFX', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '08/01/2022', 'ticker': 'RSP', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '08/01/2022', 'ticker': 'IDV', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '08/01/2022', 'ticker': 'DHS', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '08/01/2022', 'ticker': 'PCNNX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'JHCBX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'ORCL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'XLC', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'TSCO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/01/2022', 'ticker': 'MUB', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '08/01/2022', 'ticker': 'OC', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '08/26/2022', 'ticker': 'SSYS', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '08/25/2022', 'ticker': 'ARKK', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '08/18/2022', 'ticker': 'MRO', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/12/2022', 'ticker': 'X', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/05/2022', 'ticker': 'INTC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/05/2022', 'ticker': 'INTC', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '08/03/2022', 'ticker': 'CLF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/03/2022', 'ticker': 'PYPL', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '08/18/2022', 'ticker': 'SQM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/18/2022', 'ticker': 'FAST', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'MBXIX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'LUBYX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'GSIMX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'GSMYX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'FCPIX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'IJS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'JHMM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'WIW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'IVV', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'LGI', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'KRE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'CDL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'CFA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'PRF', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'EELV', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'SPGP', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'SRVR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'CEF', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'GLD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'GNR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'CIBR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'LDP', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'QTEC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'GDXJ', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'MOO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'GSSC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'SMDV', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'DGRS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'FINX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '08/10/2022', 'ticker': 'EFAD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'FDRR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'FQAL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/10/2022', 'ticker': 'JHEM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '08/09/2022', 'ticker': 'FIASX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '08/19/2022', 'ticker': 'BKEPP', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '07/18/2022', 'ticker': 'CLF', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '07/14/2022', 'ticker': 'ECOM', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '07/11/2022', 'ticker': 'GWW', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '07/01/2022', 'ticker': 'COST', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '06/23/2022', 'ticker': 'LMT', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '06/23/2022', 'ticker': 'KO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/23/2022', 'ticker': 'CSCO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/23/2022', 'ticker': 'CAT', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '12/28/2021', 'ticker': 'SBNY', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '12/28/2021', 'ticker': 'SBNY', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '12/28/2021', 'ticker': 'SBNY', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '06/16/2022', 'ticker': 'INTC', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '06/16/2022', 'ticker': 'F', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/30/2022', 'ticker': 'MMM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/01/2022', 'ticker': 'CMS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '06/17/2022', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/17/2022', 'ticker': 'IBM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/17/2022', 'ticker': 'INTC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/17/2022', 'ticker': 'KO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/17/2022', 'ticker': 'BMY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/21/2022', 'ticker': 'RPM', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '06/30/2022', 'ticker': 'VTIP', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '06/30/2022', 'ticker': 'IBDO', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '06/30/2022', 'ticker': 'IBDQ', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '06/17/2022', 'ticker': 'BRK.B', 'amount': 175000.5, 'type': 'Sale'}
# {'transaction_date': '06/29/2022', 'ticker': 'PYPL', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '06/28/2022', 'ticker': 'QCOM', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '06/28/2022', 'ticker': 'QCOM', 'amount': 375000.5, 'type': 'Sale'}
# {'transaction_date': '06/22/2022', 'ticker': 'X', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '06/22/2022', 'ticker': 'GOLD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '06/22/2022', 'ticker': 'GOLD', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '06/21/2022', 'ticker': 'X', 'amount': 175000.5, 'type': 'Purchase'}
# ...
# {'transaction_date': '05/07/2014', 'ticker': 'AMZN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '05/07/2014', 'ticker': 'ADC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/29/2014', 'ticker': 'CMRE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/29/2014', 'ticker': 'PEP', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/29/2014', 'ticker': 'GOOGL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/29/2014', 'ticker': 'CVS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/29/2014', 'ticker': 'GIS', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2014', 'ticker': 'CVS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2014', 'ticker': 'STT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/17/2014', 'ticker': 'ESRX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/17/2014', 'ticker': 'DIS', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/29/2014', 'ticker': 'EBAY', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/29/2014', 'ticker': 'JPM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/29/2014', 'ticker': 'KORS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/29/2014', 'ticker': 'ESRX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/29/2014', 'ticker': 'UTX', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '05/09/2014', 'ticker': 'VDC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '05/09/2014', 'ticker': 'ETN', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '05/09/2014', 'ticker': 'HMC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '05/09/2014', 'ticker': 'XLNX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2014', 'ticker': 'SRE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2014', 'ticker': 'XRAY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2014', 'ticker': 'UNH', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/08/2014', 'ticker': 'AMT', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/08/2014', 'ticker': 'NFLX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/28/2014', 'ticker': 'BA', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '04/28/2014', 'ticker': 'ABBV', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '04/28/2014', 'ticker': 'BUD', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '04/28/2014', 'ticker': 'F', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '04/29/2013', 'ticker': 'CG', 'amount': 175000.5, 'type': 'Purchase'}
# {'transaction_date': '04/02/2014', 'ticker': 'ATML', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2014', 'ticker': 'BHI', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '04/22/2014', 'ticker': 'KO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/22/2014', 'ticker': 'BAC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/22/2014', 'ticker': 'COP', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/23/2014', 'ticker': 'GS', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/23/2014', 'ticker': 'AXP', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/21/2014', 'ticker': 'SCHW', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/17/2014', 'ticker': 'COP', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/10/2014', 'ticker': 'FOXA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2014', 'ticker': 'LOW', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2014', 'ticker': 'LBTYK', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2014', 'ticker': 'LBTYA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2014', 'ticker': 'GOOG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/10/2014', 'ticker': 'DAL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/14/2014', 'ticker': 'GILD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/15/2014', 'ticker': 'AJG', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/11/2014', 'ticker': 'DAL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/11/2014', 'ticker': 'V', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/20/2014', 'ticker': 'C', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/20/2014', 'ticker': 'SLB', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/31/2014', 'ticker': 'BUD', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '03/31/2014', 'ticker': 'ABBV', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '04/08/2014', 'ticker': 'CAT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/09/2014', 'ticker': 'AMZN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/09/2014', 'ticker': 'FB', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/07/2014', 'ticker': 'M', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/07/2014', 'ticker': 'HON', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/28/2014', 'ticker': 'ZMH', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/28/2014', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/28/2014', 'ticker': 'AAPL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/28/2014', 'ticker': 'FCX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/28/2014', 'ticker': 'ALTR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2014', 'ticker': 'CRM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2014', 'ticker': 'CELG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/04/2014', 'ticker': 'RHHBY', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2014', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2014', 'ticker': 'M', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2014', 'ticker': 'UTX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '04/03/2014', 'ticker': 'GM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2014', 'ticker': 'CELG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2014', 'ticker': 'RHT', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/03/2014', 'ticker': 'CRM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '04/02/2014', 'ticker': 'C', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/28/2014', 'ticker': 'WIN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/31/2014', 'ticker': 'ACE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/31/2014', 'ticker': 'DAL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/28/2014', 'ticker': 'DAL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/05/2014', 'ticker': 'KSU', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/10/2014', 'ticker': 'BAC', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/14/2014', 'ticker': 'BAC', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '03/14/2014', 'ticker': 'FB', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/07/2014', 'ticker': 'AAPL', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '03/07/2014', 'ticker': 'BIDU', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/06/2014', 'ticker': 'NFLX', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '03/06/2014', 'ticker': 'NFLX', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '03/06/2014', 'ticker': 'BIDU', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '03/03/2014', 'ticker': 'BIDU', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '03/05/2014', 'ticker': 'FB', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/05/2014', 'ticker': 'FB', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/03/2014', 'ticker': 'AAPL', 'amount': 75000.5, 'type': 'Sale'}
# {'transaction_date': '03/27/2014', 'ticker': 'M', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/27/2014', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/27/2014', 'ticker': 'BIIB', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/27/2014', 'ticker': 'CELG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/17/2014', 'ticker': 'ZMH', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/13/2014', 'ticker': 'JPJQL', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '03/13/2014', 'ticker': 'CLX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/13/2014', 'ticker': 'GE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/13/2014', 'ticker': 'AAPL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/13/2014', 'ticker': 'KO', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/13/2014', 'ticker': 'VFC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/19/2014', 'ticker': 'ORCL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'VAR', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '02/19/2014', 'ticker': 'TWX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'JPM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/13/2014', 'ticker': 'VFC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/13/2014', 'ticker': 'BEAV', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '02/25/2014', 'ticker': 'DHR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/25/2014', 'ticker': 'PANW', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/25/2014', 'ticker': 'QLIK', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'V', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'EL', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'ACE', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'CLX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '03/18/2014', 'ticker': 'AIG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/19/2014', 'ticker': 'BA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/19/2014', 'ticker': 'CRM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/14/2014', 'ticker': 'AEP', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/12/2014', 'ticker': 'NWL', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/11/2014', 'ticker': 'ACE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/11/2014', 'ticker': 'VRX', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/07/2014', 'ticker': 'FB', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/07/2014', 'ticker': 'SLB', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '03/07/2014', 'ticker': 'GE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '03/04/2014', 'ticker': 'RHT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'IBM', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'VFC', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'CTSH', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2014', 'ticker': 'SJR', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/27/2014', 'ticker': 'EC', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/27/2014', 'ticker': 'RIG', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2014', 'ticker': 'VOD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/26/2014', 'ticker': 'ESRX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/26/2014', 'ticker': 'RHT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/26/2014', 'ticker': 'MCK', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/06/2014', 'ticker': 'BFK', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '02/21/2014', 'ticker': 'EPD', 'amount': 75000.5, 'type': 'Purchase'}
# {'transaction_date': '01/31/2014', 'ticker': 'CLX', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '02/10/2014', 'ticker': 'AAPL', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '02/10/2014', 'ticker': 'EMR', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/10/2014', 'ticker': 'GIS', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '02/10/2014', 'ticker': 'NSRGY', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '01/29/2014', 'ticker': 'BA', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '01/29/2014', 'ticker': 'SYMC', 'amount': 32500.5, 'type': 'Sale'}
# {'transaction_date': '02/10/2014', 'ticker': 'V', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '02/10/2014', 'ticker': 'NEE', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '02/10/2014', 'ticker': 'CMRE', 'amount': 32500.5, 'type': 'Purchase'}
# {'transaction_date': '01/29/2014', 'ticker': 'LNKD', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/31/2014', 'ticker': 'MO', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/31/2014', 'ticker': 'LOW', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/13/2014', 'ticker': 'MCK', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/19/2014', 'ticker': 'FB', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/20/2014', 'ticker': 'AIG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/12/2014', 'ticker': 'LNKD', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/11/2014', 'ticker': 'NWSA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/11/2014', 'ticker': 'CRM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/04/2014', 'ticker': 'BA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/04/2014', 'ticker': 'FB', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/04/2014', 'ticker': 'CP', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/31/2014', 'ticker': 'GE', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/07/2014', 'ticker': 'BA', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/06/2014', 'ticker': 'CVX', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '02/06/2014', 'ticker': 'MCK', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/06/2014', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/06/2014', 'ticker': 'HON', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '02/06/2014', 'ticker': 'CMCSA', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/30/2014', 'ticker': 'REGN', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/30/2014', 'ticker': 'CELG', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/30/2014', 'ticker': 'GM', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/30/2014', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/30/2014', 'ticker': 'HON', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/30/2014', 'ticker': 'CVS', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/29/2014', 'ticker': 'MSFT', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/29/2014', 'ticker': 'C', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/29/2014', 'ticker': 'C', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/28/2014', 'ticker': 'EBAY', 'amount': 8000.5, 'type': 'Sale'}
# {'transaction_date': '01/24/2014', 'ticker': 'FB', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/24/2014', 'ticker': 'CRM', 'amount': 8000.5, 'type': 'Purchase'}
# {'transaction_date': '01/24/2014', 'ticker': 'GE', 'amount': 8000.5, 'type': 'Sale'}

# %% [markdown]
# ### Downloading the return data for tickers identified in senator trades:

# %%
# Convert transaction_date to datetime object for easy comparison
for transaction in transactions:
    if isinstance(transaction['transaction_date'], str):
        transaction['transaction_date'] = datetime.strptime(transaction['transaction_date'], '%m/%d/%Y')

# %%
# Defining a function to download stock data:
def download_stock_data(transactions, start_date, end_date):
    # Create a set of unique tickers from your transactions
    unique_tickers = set(transaction['ticker'] for transaction in transactions)

    # Download stock data for the unique tickers
    try:
        transaction_data = yf.download(list(unique_tickers), start=start_date, end=end_date)
    except Exception as e:
        print(f"Error downloading data: {e}")
        transaction_data = None

    # Identify the tickers for which data could not be downloaded
    if transaction_data is not None:
        available_tickers = set(transaction_data.columns.get_level_values(1).unique())
        missing_tickers = unique_tickers - available_tickers

        # Filter out the transactions associated with missing tickers
        transactions = [trans for trans in transactions if trans['ticker'] not in missing_tickers]
    else:
        print("No stock data available.")
        transactions = []

    return transactions, transaction_data

# %% [markdown]
# # Testing Historical Performance:
# ## Test 1: 01/07/2018 - 30/06/2023

# %% [markdown]
# #### Download stock returns for relevant dates:

# %%
# Indentifying Dates
start_date = datetime(2018, 7, 1)
end_date = datetime(2023, 6, 30)

# Calling the function
filtered_transactions, transaction_data = download_stock_data(transactions, start_date, end_date)
# Out:
# [*********************100%%**********************]  1217 of 1217 completed
# 210 Failed downloads:
# ['BKEPP', 'JPJQL', 'PSXP', 'FLY', 'XON', 'STI', 'ABB', 'PKI', 'PBCT', 'WIN', 'COF-PP', 'PLT', 'RDSA', 'PDRDY', 'CERN', 'TOT', 'SPY160219P00180000', 'EPAY', 'WAGE', 'LMACU', 'KSU', 'NBL', 'RNWK', 'IBKC', 'ESV', 'FEYE', 'PHLD', 'ZNGA', 'BPL', 'CELG', 'DWDP', 'TNTOF', 'VAR', 'DLPH', 'LB', 'TRIT', 'ZAYO', 'VSI', 'AGN', 'CTAA', 'MANT', 'CBS', 'MDCA', 'AKRX', 'RHT', 'TMK', 'MAXR', 'MTSC', 'CNR', 'LMRK', 'DNKN', 'NTRP', 'CTRL', 'ADT.F', 'SYMC', 'RDS-B', 'NEE-PC', 'WETF', 'BIF', 'AVP', 'ARNA', 'LMST', 'CIT', 'RDSA.AS', 'ZIOP', 'CRZO', 'IRET', 'DFRG', 'TWTR', 'NUAN', 'IIN', 'RTN', 'ECOM', 'CONE', 'TCP', 'MXIM', 'MYL', 'ANDX', 'DISCK', 'DPM', 'VSM', 'BBL', 'HDS', 'WPX', 'HRS', 'YHOO', 'APC', 'LM09.SG', 'GRUB', 'VIAC', 'JCOM', 'CLR', 'MSTY.PA', 'CTL', 'SJR', 'BRK.B', 'ROLL', 'ICON', 'EQM', 'RAVN', 'FMBI', 'XER.BE', 'USG', 'MIK', 'ANTM', 'CSII', 'DISCA', 'CTXS', 'BRKB', 'AJRD', 'VIAB', 'CEA', 'ZNGA.SW', 'DGNR', 'SIVB', 'CMO', 'TYPE', 'BBT', 'EVOP', 'UN', 'IPHI', 'BUNT-RP', 'KL', 'WTR', 'CVET', 'DCP', 'HFC', 'COUP', 'CY', 'BLL', 'UMPQ', 'SHLX', 'EV', 'BKEP', 'FNGN', 'MDP', 'CLNY', 'UA-C', 'FB', 'MCC', 'AQFH', 'SI', 'CHL', 'XLNX', 'RDS-A', 'ROC', 'UTX', 'FDC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['NTI', 'VRX', 'CMN', 'POT', 'IPCM', 'SGY', 'MFRM', 'HTS', 'PWE', 'HUB-B', 'PCLN', 'LDR', 'HOT', 'CMCSK', 'BIVV', 'CTCT', 'QLIK', 'RAI', 'ISIS', 'LOCK', 'Q', 'PLKI', 'BCR', 'TLLP', 'SQI', 'CYBX', 'AMSG', 'TWX', 'ATML', 'LGP', 'PGH', 'BUNT', 'COH', 'TNGO', 'WFM', 'LLTC', 'AXLL', 'LNKD', 'CPGX', 'NPSND', 'LINE', 'BEAV', 'HYH', 'TUMI', 'ZMH', 'CVC', 'AGU', 'KRFT', 'DPS', 'OKS', 'NGLS', 'ENTL', 'BHI', 'NGIPX', 'TCAP', 'KORS', 'FMER', 'CAB']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-07-01 00:00:00 -> 2023-06-30 00:00:00)')
# ['ABC', '3V64.TI']: Exception('%ticker%: No data found, symbol may be delisted')
# ['HF']: Exception("%ticker%: Data doesn't exist for startDate = 1530417600, endDate = 1688097600")
# ['XLS-WI']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")

# %% [markdown]
# #### Calculating Portfolio Weights:

# %%
# Filter transactions after the start date and sort them by date
filtered_transactions = sorted([t for t in transactions if t['transaction_date'] >= start_date], key=lambda x: x['transaction_date'])

# Calculate cumulative amounts by ticker for each date
cumulative_amounts = defaultdict(float)
datewise_weightings = {}

for transaction in filtered_transactions:
    multiplier = -1 if transaction['type'] == 'Sale' else 1
    cumulative_amounts[transaction['ticker']] += multiplier * transaction['amount']
    
    # Calculate absolute total transaction amount for the current date
    absolute_total = sum(abs(value) for value in cumulative_amounts.values())
    
    # Calculate weightings by ticker for the current date
    weightings = {}
    for ticker, amount in cumulative_amounts.items():
        weightings[ticker] = amount / absolute_total if absolute_total != 0 else 0
    
    # Normalize the weightings to ensure their absolute sum equals 1
    absolute_sum_weights = sum(abs(weight) for weight in weightings.values())
    for ticker, weight in weightings.items():
        weightings[ticker] = weight / absolute_sum_weights
    
    datewise_weightings[transaction['transaction_date']] = weightings

def get_weightings_on_date(date):
    """Return the portfolio weightings on a given date."""
    # Convert string date to datetime object
    date_obj = datetime.strptime(date, '%m/%d/%Y')
    
    # Find the most recent date before or on the given date
    relevant_date = max(d for d in datewise_weightings if d <= date_obj)
    
    return datewise_weightings[relevant_date]

# Example: Get weightings on '04/05/2023'
print(get_weightings_on_date('04/05/2023'))
# Out:
# {'MYL': -0.0006705130515783654, 'GLD': 7.348396497541437e-05, 'FB': -0.0030861336456145523, 'NOC': -0.00019285579808621652, 'TGT': -0.0010654600863837314, 'BAC': -0.002741722049256125, 'DHR': -0.0005924504032031329, 'DISCA': -0.0026545801059145533, 'GM': -0.00035355977823649937, 'MCHP': -0.0008955436299044265, 'AVP': -7.348396497541437e-05, 'FDC': -0.0021539284012861066, 'CELG': -0.00044548247325230424, 'LYV': -0.0006705130515783654, 'RF': -0.00017448595495755847, 'GPK': -0.0010286515132146826, 'BOIVF': 0.000707321624747414, 'NFLX': 0.0004960179116992425, 'SBUX': -7.806264837523238e-05, 'ENB': -0.00022503057832606112, 'KN': -0.0006613556847787292, 'IIN': -0.0016073658662183615, 'BFAM': -0.0009873882530869347, 'WTW': 0.0013088513229168861, 'REVB': -0.000597029086602951, 'AXTA': -0.0013914926546919365, 'UNFI': -7.348396497541437e-05, 'NVDA': -0.0011021217008077505, 'AAPL': -0.007513256654699579, 'AMZN': -0.0017175114456177954, 'JPM': -0.000597029086602951, 'BA': 0.000128607271743735, 'WPX': 0.0005098090714280826, 'CBS': 0.0008174809815291941, 'BBT': 0.0, 'MOS': -0.0016992885612341663, 'CZR': -0.002057551019311602, 'PG': -0.004156232117388269, 'GLW': -0.0016119445496181794, 'CAT': -0.001175665367773333, 'T': -0.002819784697631357, 'BRK-B': 0.0002709873333731814, 'WBA': 0.0, 'MDLZ': -0.0030402365925576, 'GE': -0.0004960270966208069, 'FEYE': -0.0017543337961691903, 'PFE': -0.0036556355222892092, 'CAPL': -0.00014696792995082874, 'BAM': -0.0018232298928232223, 'INTU': -7.348396497541437e-05, 'BKNG': -0.0009093256047117022, 'WMB': -0.0015614779980829738, 'XOM': -0.0026590531627163814, 'DVN': -0.0004775883665804163, 'GDV': -0.00014696792995082874, 'HBI': -0.0014649766196673508, 'KSS': 0.0, 'NKE': -0.0007439970165537798, 'CB': -0.00044548247325230424, 'GS': -0.0009873882530869347, 'BABA': 0.0016946226210794873, 'LRCX': 0.0002204518949262431, 'WMT': -0.002144692962653174, 'PODD': -0.007187214901469809, 'CUTR': -0.0016808498311937758, 'WFC': 0.0003628411414772538, 'F': -0.00022503057832606112, 'EQM': 0.0, 'OKE': -0.0004409037898524862, 'MU': -0.00010100198998214412, 'TBT': -0.00014696792995082874, 'WES': -7.348396497541437e-05, 'ANDX': 7.348396497541437e-05, 'TRP': -0.00029393585990165747, 'EPD': -0.0006153897448100447, 'FDX': 0.000891033833416341, 'SHLX': 7.348396497541437e-05, 'MMP': -0.00022503057832606112, 'GILD': 0.0, 'RPM': -0.004711910687108611, 'QCOM': -0.0015568901297615915, 'WAB': 7.348396497541437e-05, 'ON': -7.348396497541437e-05, 'XPO': -0.0002985145433014755, 'IWF': -0.0003719985082768899, 'MRK': -0.0040827481524128555, 'LEA': -0.0002985145433014755, 'APTV': -0.0002985145433014755, 'GOOGL': -0.00741224547979587, 'ENTG': -0.001400774017932691, 'MTUM': 0.0003719985082768899, 'CRM': -0.000688873709785459, 'HON': -0.002351362882772141, 'TJX': -0.00015154661335064676, 'SLB': -0.00027557520169456374, 'JNJ': -0.00017448595495755847, 'ALB': 0.00019751255331933135, 'VLP': -0.0003674198248770718, 'IP': -0.0005235451216275365, 'ISRG': -0.00014696792995082874, 'NTLA': -0.00022503057832606112, 'MSTY.PA': 0.001377747419570918, 'AON': -0.00014696792995082874, 'AIG': 0.0010792328762694427, 'LGF-B': 0.002186158291055337, 'GIS': 0.0, 'INCY': -7.348396497541437e-05, 'SHECY': -7.348396497541437e-05, 'KHC': -0.0033616996623875516, 'IBM': -0.00027099651829474574, 'SPY': 0.03658354718318329, 'HOLX': -7.348396497541437e-05, 'AGN': -0.0035178341440595807, 'KMI': -0.0016808498311937758, 'C': -0.0030310792257579643, 'BUD': -0.001060872218062349, 'REZI': -0.002815206014231539, 'ETN': -7.348396497541437e-05, 'UNP': -0.0002985145433014755, 'WY': -0.000688873709785459, 'VZ': -0.00411944191406235, 'USB': -0.00022503057832606112, 'RDS-B': -7.348396497541437e-05, 'MSFT': -0.002599378727312936, 'LM09.SG': 0.0, 'DIS': -0.0003719709535121969, 'DVA': 7.348396497541437e-05, 'COST': -0.0018461784193516985, 'GOOG': 0.002250351707868433, 'ABBV': -0.0038163486873610563, 'BRKB': 0.0002985145433014755, 'BWXT': -0.00044548247325230424, 'NVS': -0.00014696792995082874, 'M ...

# %% [markdown]
# #### Calculating Portfolio Value - Long and Short Positions:

# %%
# Calculate daily returns from price data
daily_returns = transaction_data['Close'].pct_change()

# Initialize the portfolio value and cash. We'll start with an initial cash of, say, $100,000.
cash = 100000.0

portfolio_value = []
portfolio_dates = []

# Loop only over trading days present in daily_returns.index
for date in daily_returns.index:
    if date in datewise_weightings:
        # Calculate the value based on weightings and daily returns for that date
        daily_portfolio_return = sum(datewise_weightings[date].get(ticker, 0) * (daily_returns.loc[date, ticker] if not np.isnan(daily_returns.loc[date, ticker]) else 0) for ticker in datewise_weightings[date] if ticker in daily_returns.columns)
        cash *= (1 + daily_portfolio_return)
    # Append to portfolio_value and portfolio_dates
    portfolio_value.append(cash)
    portfolio_dates.append(date)

# Convert portfolio_value list into a pandas series using portfolio_dates for the index
portfolio_value_series = pd.Series(portfolio_value, index=portfolio_dates)

# Plotting the portfolio value
plt.plot(portfolio_value_series)
plt.title("Portfolio Value Over Time")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")
plt.grid(True)
plt.show()
# Out:
# C:\Users\abbye\AppData\Local\Temp\ipykernel_3228\1172304053.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   daily_returns = transaction_data['Close'].pct_change()

# %% [markdown]
# #### Calculating Portfolio Value - Long only Positions:

# %%
# Assuming you have the datewise_weightings and transaction_data already from previous code

# Calculate daily returns from price data
daily_returns = transaction_data['Close'].pct_change()

# Initialize the portfolio value and cash. We'll start with an initial cash of, say, $100,000.
cash = 100000.0

portfolio_value = []
portfolio_dates = []

# Loop only over trading days present in daily_returns.index
for date in daily_returns.index:
    if date in datewise_weightings:
        # Calculate the value based on weightings and daily returns for that date
        
        # Prevent shorts by setting negative weightings to zero
        adjusted_weightings = {ticker: max(0, weight) for ticker, weight in datewise_weightings[date].items()}
        
        daily_portfolio_return = sum(adjusted_weightings.get(ticker, 0) * (daily_returns.loc[date, ticker] if not np.isnan(daily_returns.loc[date, ticker]) else 0) for ticker in adjusted_weightings if ticker in daily_returns.columns)
        
        cash *= (1 + daily_portfolio_return)
        
    # Append to portfolio_value and portfolio_dates
    portfolio_value.append(cash)
    portfolio_dates.append(date)

# Convert portfolio_value list into a pandas series using portfolio_dates for the index
portfolio_value_series = pd.Series(portfolio_value, index=portfolio_dates)

# Plotting the portfolio value
plt.plot(portfolio_value_series)
plt.title("Portfolio Value Over Time (No Shorts)")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")
plt.grid(True)
plt.show()
# Out:
# C:\Users\abbye\AppData\Local\Temp\ipykernel_3228\226770288.py:4: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   daily_returns = transaction_data['Close'].pct_change()

# %% [markdown]
# #### Comparing Against a Benchmark:
# The S&P 500 has been used as a benchmark

# %%
# Using your logic for Portfolio Value Over Time
daily_returns_long_short = []
cash = 100000.0
for date in daily_returns.index:
    if date in datewise_weightings:
        daily_portfolio_return = sum(datewise_weightings[date].get(ticker, 0) * (daily_returns.loc[date, ticker] if not np.isnan(daily_returns.loc[date, ticker]) else 0) for ticker in datewise_weightings[date] if ticker in daily_returns.columns)
        cash *= (1 + daily_portfolio_return)
        daily_returns_long_short.append(daily_portfolio_return)
    else:
        daily_returns_long_short.append(0)

# Using your logic for Portfolio Value Over Time (No Shorts)
daily_returns_long_only = []
cash = 100000.0
for date in daily_returns.index:
    if date in datewise_weightings:
        adjusted_weightings = {ticker: max(0, weight) for ticker, weight in datewise_weightings[date].items()}
        daily_portfolio_return = sum(adjusted_weightings.get(ticker, 0) * (daily_returns.loc[date, ticker] if not np.isnan(daily_returns.loc[date, ticker]) else 0) for ticker in adjusted_weightings if ticker in daily_returns.columns)
        cash *= (1 + daily_portfolio_return)
        daily_returns_long_only.append(daily_portfolio_return)
    else:
        daily_returns_long_only.append(0)

def calculate_cumulative_return(daily_returns):
    return (1 + daily_returns).cumprod() - 1

# Convert lists to pandas Series with appropriate datetime index
daily_returns_long_short_series = pd.Series(daily_returns_long_short, index=daily_returns.index)
daily_returns_long_only_series = pd.Series(daily_returns_long_only, index=daily_returns.index)

cumulative_returns_long_short = calculate_cumulative_return(daily_returns_long_short_series)
cumulative_returns_long_only = calculate_cumulative_return(daily_returns_long_only_series)

sp500 = yf.download('^GSPC', start=start_date, end=end_date)
sp500_returns = sp500['Close'].pct_change().dropna()
sp500_cumulative_returns = calculate_cumulative_return(sp500_returns)

plt.figure(figsize=(12,6))
plt.plot(cumulative_returns_long_short.loc[start_date:end_date], label="Portfolio (Long & Short)")
plt.plot(cumulative_returns_long_only.loc[start_date:end_date], label="Portfolio (Long-Only)")
plt.plot(sp500_cumulative_returns.loc[start_date:end_date], label="S&P500")
plt.legend()
plt.title('Cumulative Returns Over Time')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.grid(True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Testing Historical Performance:
# ## Test 2: 01/01/2020 - 30/06/2023

# %% [markdown]
# #### Download stock returns for relevant dates:

# %%
# Indentifying Dates
start_date_2 = datetime(2020, 1, 1)
end_date_2 = datetime(2023, 6, 30)

# Calling the function
filtered_transactions, transaction_data = download_stock_data(transactions, start_date, end_date)
# Out:
# [*********************100%%**********************]  1217 of 1217 completed
# 207 Failed downloads:
# ['BKEPP', 'PSXP', 'JPJQL', 'FLY', 'XON', 'STI', 'ABB', 'PKI', 'PBCT', 'COF-PP', 'WIN', 'PLT', 'RDSA', 'PDRDY', 'CERN', 'TOT', 'SPY160219P00180000', 'EPAY', 'KSU', 'WAGE', 'LMACU', 'NBL', 'RNWK', 'IBKC', 'ESV', 'FEYE', 'PHLD', 'ZNGA', 'BPL', 'CELG', 'DWDP', 'TNTOF', 'VAR', 'LB', 'DLPH', 'TRIT', 'ZAYO', 'VSI', 'AGN', 'CTAA', 'MANT', 'CBS', 'MDCA', 'AKRX', 'RHT', 'TMK', 'MAXR', 'MTSC', 'CNR', 'LMRK', 'DNKN', 'NTRP', 'CTRL', 'ADT.F', 'SYMC', 'RDS-B', 'NEE-PC', 'WETF', 'BIF', 'AVP', 'ARNA', 'LMST', 'CIT', 'RDSA.AS', 'ZIOP', 'CRZO', 'IRET', 'DFRG', 'TWTR', 'NUAN', 'IIN', 'RTN', 'ECOM', 'CONE', 'TCP', 'MXIM', 'MYL', 'ANDX', 'DISCK', 'DPM', 'VSM', 'BBL', 'HDS', 'WPX', 'HRS', 'YHOO', 'APC', 'LM09.SG', 'GRUB', 'VIAC', 'JCOM', 'CLR', 'MSTY.PA', 'CTL', 'SJR', 'BRK.B', 'ROLL', 'ICON', 'EQM', 'RAVN', 'FMBI', 'XER.BE', 'USG', 'MIK', 'ANTM', 'CSII', 'DISCA', 'CTXS', 'BRKB', 'AJRD', 'VIAB', 'CEA', 'ZNGA.SW', 'DGNR', 'SIVB', 'CMO', 'TYPE', 'BBT', 'EVOP', 'UN', 'IPHI', 'BUNT-RP', 'KL', 'WTR', 'CVET', 'DCP', 'HFC', 'COUP', 'CY', 'BLL', 'UMPQ', 'SHLX', 'EV', 'BKEP', 'FNGN', 'MDP', 'CLNY', 'UA-C', 'FB', 'MCC', 'AQFH', 'CHL', 'SI', 'XLNX', 'RDS-A', 'ROC', 'UTX', 'FDC']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['NTI', 'VRX', 'CMN', 'POT', 'IPCM', 'SGY', 'MFRM', 'HTS', 'PWE', 'HUB-B', 'PCLN', 'LDR', 'HOT', 'CMCSK', 'BIVV', 'CTCT', 'QLIK', 'RAI', 'ISIS', 'LOCK', 'Q', 'PLKI', 'BCR', 'TLLP', 'SQI', 'CYBX', 'AMSG', 'TWX', 'ATML', 'LGP', 'PGH', 'BUNT', 'COH', 'TNGO', 'WFM', 'LLTC', 'AXLL', 'LNKD', 'CPGX', 'NPSND', 'LINE', 'BEAV', 'HYH', 'TUMI', 'ZMH', 'CVC', 'AGU', 'KRFT', 'DPS', 'OKS', 'NGLS', 'ENTL', 'NGIPX', 'KORS', 'FMER']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2018-07-01 00:00:00 -> 2023-06-30 00:00:00)')
# ['ABC', '3V64.TI']: Exception('%ticker%: No data found, symbol may be delisted')
# ['HF']: Exception("%ticker%: Data doesn't exist for startDate = 1530417600, endDate = 1688097600")
# ['XLS-WI']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")

# %% [markdown]
# #### Calculating Portfolio Weights:

# %%
# Filter transactions after the start date and sort them by date
filtered_transactions = sorted([t for t in transactions if t['transaction_date'] >= start_date_2], key=lambda x: x['transaction_date'])

# Calculate cumulative amounts by ticker for each date
cumulative_amounts = defaultdict(float)
datewise_weightings = {}

for transaction in filtered_transactions:
    multiplier = -1 if transaction['type'] == 'Sale' else 1
    cumulative_amounts[transaction['ticker']] += multiplier * transaction['amount']
    
    # Calculate absolute total transaction amount for the current date
    absolute_total = sum(abs(value) for value in cumulative_amounts.values())
    
    # Calculate weightings by ticker for the current date
    weightings = {}
    for ticker, amount in cumulative_amounts.items():
        weightings[ticker] = amount / absolute_total if absolute_total != 0 else 0
    
    # Normalize the weightings to ensure their absolute sum equals 1
    absolute_sum_weights = sum(abs(weight) for weight in weightings.values())
    for ticker, weight in weightings.items():
        weightings[ticker] = weight / absolute_sum_weights
    
    datewise_weightings[transaction['transaction_date']] = weightings

def get_weightings_on_date(date):
    """Return the portfolio weightings on a given date."""
    # Convert string date to datetime object
    date_obj = datetime.strptime(date, '%m/%d/%Y')
    
    # Find the most recent date before or on the given date
    relevant_date = max(d for d in datewise_weightings if d <= date_obj)
    
    return datewise_weightings[relevant_date]

# %% [markdown]
# #### Calculating Portfolio Value - Long and Short Positions:

# %%
# Calculate daily returns from price data
daily_returns = transaction_data['Close'].pct_change()

# Initialize the portfolio value and cash. We'll start with an initial cash of, say, $100,000.
cash = 100000.0

portfolio_value = []
portfolio_dates = []

# Loop only over trading days present in daily_returns.index
for date in daily_returns.index:
    if date in datewise_weightings:
        # Calculate the value based on weightings and daily returns for that date
        daily_portfolio_return = sum(datewise_weightings[date].get(ticker, 0) * (daily_returns.loc[date, ticker] if not np.isnan(daily_returns.loc[date, ticker]) else 0) for ticker in datewise_weightings[date] if ticker in daily_returns.columns)
        cash *= (1 + daily_portfolio_return)
    # Append to portfolio_value and portfolio_dates
    portfolio_value.append(cash)
    portfolio_dates.append(date)

# Convert portfolio_value list into a pandas series using portfolio_dates for the index
portfolio_value_series = pd.Series(portfolio_value, index=portfolio_dates)

# Plotting the portfolio value
plt.plot(portfolio_value_series)
plt.title("Portfolio Value Over Time")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")
plt.grid(True)
plt.show()
# Out:
# C:\Users\abbye\AppData\Local\Temp\ipykernel_3228\4115295516.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   daily_returns = transaction_data['Close'].pct_change()

# %% [markdown]
# #### Calculating Portfolio Value - Long only Position

# %%
# Assuming you have the datewise_weightings and transaction_data already from previous code

# Calculate daily returns from price data
daily_returns = transaction_data['Close'].pct_change()

# Initialize the portfolio value and cash. We'll start with an initial cash of, say, $100,000.
cash = 100000.0

portfolio_value = []
portfolio_dates = []

# Loop only over trading days present in daily_returns.index
for date in daily_returns.index:
    if date in datewise_weightings:
        # Calculate the value based on weightings and daily returns for that date
        
        # Prevent shorts by setting negative weightings to zero
        adjusted_weightings = {ticker: max(0, weight) for ticker, weight in datewise_weightings[date].items()}
        
        daily_portfolio_return = sum(adjusted_weightings.get(ticker, 0) * (daily_returns.loc[date, ticker] if not np.isnan(daily_returns.loc[date, ticker]) else 0) for ticker in adjusted_weightings if ticker in daily_returns.columns)
        
        cash *= (1 + daily_portfolio_return)
        
    # Append to portfolio_value and portfolio_dates
    portfolio_value.append(cash)
    portfolio_dates.append(date)

# Convert portfolio_value list into a pandas series using portfolio_dates for the index
portfolio_value_series = pd.Series(portfolio_value, index=portfolio_dates)

# Plotting the portfolio value
plt.plot(portfolio_value_series)
plt.title("Portfolio Value Over Time (No Shorts)")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")
plt.grid(True)
plt.show()
# Out:
# C:\Users\abbye\AppData\Local\Temp\ipykernel_3228\1341721112.py:4: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   daily_returns = transaction_data['Close'].pct_change()

# %% [markdown]
# #### Comparing Against a Benchmark:

# %%
# Using your logic for Portfolio Value Over Time
daily_returns_long_short = []
cash = 100000.0
for date in daily_returns.index:
    if date in datewise_weightings:
        daily_portfolio_return = sum(datewise_weightings[date].get(ticker, 0) * (daily_returns.loc[date, ticker] if not np.isnan(daily_returns.loc[date, ticker]) else 0) for ticker in datewise_weightings[date] if ticker in daily_returns.columns)
        cash *= (1 + daily_portfolio_return)
        daily_returns_long_short.append(daily_portfolio_return)
    else:
        daily_returns_long_short.append(0)

# Using your logic for Portfolio Value Over Time (No Shorts)
daily_returns_long_only = []
cash = 100000.0
for date in daily_returns.index:
    if date in datewise_weightings:
        adjusted_weightings = {ticker: max(0, weight) for ticker, weight in datewise_weightings[date].items()}
        daily_portfolio_return = sum(adjusted_weightings.get(ticker, 0) * (daily_returns.loc[date, ticker] if not np.isnan(daily_returns.loc[date, ticker]) else 0) for ticker in adjusted_weightings if ticker in daily_returns.columns)
        cash *= (1 + daily_portfolio_return)
        daily_returns_long_only.append(daily_portfolio_return)
    else:
        daily_returns_long_only.append(0)

def calculate_cumulative_return(daily_returns):
    return (1 + daily_returns).cumprod() - 1

# Convert lists to pandas Series with appropriate datetime index
daily_returns_long_short_series = pd.Series(daily_returns_long_short, index=daily_returns.index)
daily_returns_long_only_series = pd.Series(daily_returns_long_only, index=daily_returns.index)

cumulative_returns_long_short = calculate_cumulative_return(daily_returns_long_short_series)
cumulative_returns_long_only = calculate_cumulative_return(daily_returns_long_only_series)

sp500 = yf.download('^GSPC', start=start_date_2, end=end_date_2)
sp500_returns = sp500['Close'].pct_change().dropna()
sp500_cumulative_returns = calculate_cumulative_return(sp500_returns)

plt.figure(figsize=(12,6))
plt.plot(cumulative_returns_long_short.loc[start_date_2:end_date_2], label="Portfolio (Long & Short)")
plt.plot(cumulative_returns_long_only.loc[start_date_2:end_date_2], label="Portfolio (Long-Only)")
plt.plot(sp500_cumulative_returns.loc[start_date_2:end_date_2], label="S&P500")
plt.legend()
plt.title('Cumulative Returns Over Time')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.grid(True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # References
# 112th Congress. (2012). Public Law 112-105 Stock Act.
#
# Kelly, K., Playford, A., & Parlapiano, A. (2022, September 13). Stock Trades Reported by Nearly a Fifth of Congress Show Possible Conflicts. Retrieved from The New York Times: https://www.nytimes.com/interactive/2022/09/13/us/politics/congress-stock-trading-investigation.html
#
# Quiver Quantitative . (2023, October). Senate Trading. Retrieved from Quiver Quantitative : https://www.quiverquant.com/sources/senatetrading
#
# Ridge, J. (2022, October 20). Study: Stock Purchases by Senators Generate Abnormal Returns for Firms. Retrieved from University of Arkansas: https://news.uark.edu/articles/62333/study-stock-purchases-by-senators-generate-abnormal-returns-for-firms
